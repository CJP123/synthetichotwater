# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = (pd.read_csv('../synthetichotwater/OutputData/nominal/synthetic_profile[0].csv')
.assign(timestamp = lambda x: pd.date_range(start='1/1/2023', periods=28*24*60, freq='60S'))
.set_index('timestamp')
)

# %%
df
# Out:
#                      Summer[differentiated_days]  Autumn[differentiated_days]  \
# timestamp
# 2023-01-01 00:00:00                          0.0                          0.0
# 2023-01-01 00:01:00                          0.0                          0.0
# 2023-01-01 00:02:00                          0.0                          0.0
# 2023-01-01 00:03:00                          0.0                          0.0
# 2023-01-01 00:04:00                          0.0                          0.0
# ...                                          ...                          ...
# 2023-01-28 23:55:00                          0.0                          0.0
# 2023-01-28 23:56:00                          0.0                          0.0
# 2023-01-28 23:57:00                          0.0                          0.0
# 2023-01-28 23:58:00                          0.0                          0.0
# 2023-01-28 23:59:00                          0.0                          0.0
#
# ...

# %%
df.loc['2023-01-04'].loc[:,'Summer[undifferentiated_days]'].sum()
# Out:
# 107.0
